# %% [markdown]
# ## Машинное обучение, ФКН ВШЭ
#
# ## Практическое задание 2
#
# ### Общая информация
# Дата выдачи: 17.09.2018
#
# Мягкий дедлайн: 2:59MSK 24.09.2018
#
# Жесткий дедлайн: 23:59MSK 26.09.2018

# %% [markdown]
# ### О задании
# Задание состоит из двух частей:
#
# __Первая часть__ задания посвящена получению студентами навыков работы с библиотекой векторного вычисления numpy и библиотеками для построения графиков matplotlib/plotly. Это задание сдается частично в Яндекс.Контест (см. информацию ниже). В случае проблем с доступом к Яндекс.Контесту обращайтесь к своему семинаристу(ке).
#
# __Вторая часть__ задания посвящена обучению линейной регрессии, подбору гиперпараметров и работе с данными.
#
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце Вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
#
# ### Формат сдачи
# Ipython Notebook с выполненым заданием необходимо сдать в Anytask (lab_02). Также обратите внимание, что в первой части про Numpy также необходимо сделать две посылки в Яндекс.Контест.

# %% [markdown]
# # Часть 1. Numpy

# %% [markdown]
# ### Задачи 1-6
# __(2.4 балла)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.15 балла__, векторизованная – в __0.25 балла__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py (см. шаблоны). Далее эти файлы необходимо сдать в Яндекс.Контест: https://official.contest.yandex.ru/contest/9148/enter/ в соответствующие задачи. По техническим причинам тестирование проводится на этапе компиляции, поэтому в случае любой ошибки вы будете получать вердикт CE, и в логе компиляции можно будет посмотреть, в чем проблема. Частичное выполнение задания (не все задачи) будет оцениваться, хотя и будет получать вердикт CE. Для удобства проверки приложите в ячейке ниже ссылки на самые успешные посылки.
#
#
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.
#
#
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow). __Обратите внимание, что в изображении может быть не три канала! За решения, явно или неявно использующие трёхканальность изображения будет присуждена половина баллов.__
#
#
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).
#
# __Замечание.__ Можно считать, что все указанные объекты непустые (к примеру, в __задаче 1__ на диагонали матрицы есть ненулевые элементы) и корректные.

# %% [markdown]
# **Задача 4**

# %%
from IPython.display import Image
Image(filename='img.png')

# %%
Image(filename='result.png')

# %% [markdown]
# **Задача 6**
# *%timeit невекторизованной :*
# 24.9 µs ± 506 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# *Векторизованной :*
# 376 µs ± 10.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# *scipy.spatial.distance.cdist :*
# 98.7 µs ± 1.73 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# для [[1, 2], [3, 4]], [[5, 6], [7, 8]] в качестве аргумента

# %% [markdown]
# __Укажите ссылки на посылки__
#
# Посылка по невекторизованным функциям: 12046531
# https://contest.yandex.ru/contest/9148/run-report/12046531/
# Посылка по векторизованным функциям: 12055190
# https://contest.yandex.ru/contest/9148/run-report/12055190/

# %% [markdown]
# ### Задача 7
# __(1.6 балла)__
# Для каждой задачи сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib или plotly постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))


ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
import timeit
import numpy as np
import functions as func
import functions_vectorized as func_v

np.random.seed(0)
N = 101
REPEATS = 1000
STEP = 5

data_size = np.arange(1, N, STEP)
time_vectorized = data_size.astype('float')
time_non_vectorized = data_size.astype('float')

def exec_time(func, *args, **kwargs):
    return timeit.timeit(lambda: func(*args, **kwargs), number = REPEATS)

def reset():
    global time_non_vectorized, time_vectorized, data_size
    data_size = np.arange(1, N, STEP)
    time_vectorized = data_size.astype('float')
    time_non_vectorized = data_size.astype('float')

def draw_plot(name, xlabel):
    global time_non_vectorized, time_vectorized, data_size
    f, ax = plt.subplots(figsize=(13, 5))
    ax.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
    ax.plot(data_size, time_vectorized, label=u"Векторизованная")
    ax.set_title(u"Общее время выполнения для " + name + " с числом повторений " + str(REPEATS))
    ax.set_xlabel(xlabel)
    ax.set_ylabel(u"Время (с)")
    ax.grid()
    ax.legend()
    f.show()

#reset()
for n in range(1, N, STEP):
    buf = np.random.randint(0, n, (n, n))
    time_non_vectorized[n // STEP] = exec_time(func.prod_non_zero_diag, buf)
    time_vectorized[n // STEP] = exec_time(func_v.prod_non_zero_diag, buf)
draw_plot("prod_non_zero_diag", u"Длина массива (x из x*x размера матрицы)")
# Out:
# /mnt/c/work/Machine learning/2/functions.py:16: RuntimeWarning: overflow encountered in long_scalars
#   ans *= x[i][i]
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
N = 10000
STEP = 50
REPEATS = 10
reset()
for n in range(1, N, STEP):
    buf1 = np.random.randint(0, n, size = n)
    buf2 = np.random.randint(0, n, size = n)
    time_non_vectorized[n // STEP] = exec_time(func.are_multisets_equal, buf1, buf2)
    time_vectorized[n // STEP] = exec_time(func_v.are_multisets_equal, buf1, buf2)
draw_plot("are_multisets_equal", u"Длина массива обоих")
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
N = 10000
STEP = 50
REPEATS = 10
reset()
for n in range(0, N, STEP):
    buf = np.r_[np.random.randint(0, 10, size = n), 0]
    time_non_vectorized[n // STEP] = exec_time(func.max_after_zero, buf)
    time_vectorized[n // STEP] = exec_time(func_v.max_after_zero, buf)
draw_plot("max_after_zero", u"Длина массива")
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
N = 50
STEP = 5
REPEATS = 3
reset()
for n in range(1, N, STEP):
    buf1 = np.random.randint(0, 255, size = (n, n, n))
    buf2 = np.random.randint(0, 255, size = n)
    time_non_vectorized[n // STEP] = exec_time(func.convert_image, buf1, buf2)
    time_vectorized[n // STEP] = exec_time(func_v.convert_image, buf1, buf2)
draw_plot("convert_image", u"Длина массива (x из x*x*x размера первой матрицы), второго x")
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
N = 10000
STEP = 50
REPEATS = 10
reset()
for n in range(1, N, STEP):
    buf = np.random.randint(0, 10, size = n)
    time_non_vectorized[n // STEP] = exec_time(func.run_length_encoding, buf)
    time_vectorized[n // STEP] = exec_time(func_v.run_length_encoding, buf)
draw_plot("run_length_encoding", u"Длина массива")
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
N = 50
STEP = 5
REPEATS = 3
reset()
for n in range(1, N, STEP):
    buf1 = np.random.randint(0, 10, size = (n, n))
    buf2 = np.random.randint(0, 10, size = (n, n))
    time_non_vectorized[n // STEP] = exec_time(func.pairwise_distance, buf1, buf2)
    time_vectorized[n // STEP] = exec_time(func_v.pairwise_distance, buf1, buf2)
draw_plot("pairwise_distance", u"Длина массива (x из x*x для обоих")
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ---

# %% [markdown]
# # Часть 2. Линейная регрессия

# %%
# %pylab inline

import seaborn as sns
sns.set(style="whitegrid")

from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def pairplot(df, target):
    ncol, nrow = 7, df.shape[1] // 7 + (df.shape[1] % 7 > 0)
    plt.figure(figsize=(ncol * 4, nrow * 4))

    for i, feature in enumerate(df.columns):
        plt.subplot(nrow, ncol, i + 1)
        plt.scatter(df[feature], target, s=10, marker='o', alpha=.6)
        plt.xlabel(feature)
        if i % ncol == 0:
            plt.ylabel('target')

# %% [markdown]
# В данном задании мы рассмотрим стандартный датасет для задачи регрессии Boston Housing, в котором необходимо предсказать стоимость недвижимости по 13 признакам.
#
# Датасет достаточно просто загрузить из библиотеки scikit-learn:

# %%
data = datasets.load_boston()
df = pd.DataFrame(data.data)
df.columns = data.feature_names
y = data.target

# %%
print(data['DESCR'])
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# Разделим выборку на обучающую и тестовую в отношении 8/2:

# %%
x_train, x_test, y_train, y_test = train_test_split(df, y, train_size=0.8, random_state=42)
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# __Задание 1.__ Обучение линейной регрессии.
#
# **(0.5 балл)**
#
# Обучите стандартную линейную регрессию, а также с $L_1$ и $L_2$ регуляризаторами (используйте параметры по умолчанию). Посчитайте метрику $R^2$ для каждого метода (метод score).

# %%
from sklearn.metrics import r2_score

model0 = LinearRegression()
model1 = Lasso()
model2 = Ridge()

model0.fit(x_train, y_train)
model1.fit(x_train, y_train)
model2.fit(x_train, y_train)

p0_test = model0.predict(x_test)
p1_test = model1.predict(x_test)
p2_test = model2.predict(x_test)

print('R2 Score\n')
print('For Linear Regression %.3f\n' % r2_score(y_test, p0_test))
print('For Lasso regularization %.3f\n' % r2_score(y_test, p1_test))
print('For Ridge regularization %.3f\n' % r2_score(y_test, p2_test))
# Out:
# R2 Score
#
# For Linear Regression 0.668
#
# For Lasso regularization 0.667
#
# For Ridge regularization 0.666

# %% [markdown]
# __Задание 2.__ Подбор гиперпараметров.
#
# **(1 балл)**
#
# Для Lasso- и Ridge-регресий подберите коэффициент регуляризации по обучающей выборке с помощью кросс-валидации. Параметры для перебора возьмите по логарифмической сетке от $10^{-6}$ до $10^6$).
# Также посчитайте метрику $R^2$ для тестовой выборки и сравните с предыдущими результатами. Заметно ли изменилось качество?
#
# Useful: GridSearchCV, RidgeCV, LassoCV

# %%
from sklearn.linear_model import RidgeCV, Ridge, LassoCV, ElasticNetCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PolynomialFeatures
from sklearn.model_selection import GridSearchCV

train_x, train_y = x_train, y_train

'''
def mape(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
def mape_scorer(estimator, X_test, y_test): 
    return -mape(y_test, estimator.predict(X_test))
'''

def r2_scorer(estimator, X_test, y_test):
    return r2_score(y_test, estimator.predict(X_test))

params = {
    'alpha': np.logspace(-6, 6, 100)
}

cv0 = GridSearchCV(Lasso(), params, cv=4, scoring=r2_scorer)
cv0.fit(train_x, train_y)
cv1 = GridSearchCV(Ridge(), params, cv=4, scoring=r2_scorer)
cv1.fit(train_x, train_y)
# Out:
# GridSearchCV(cv=4, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'alpha': array([  1.00000e-06,   1.32194e-06, ...,   7.56463e+05,   1.00000e+06])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=<function r2_scorer at 0x7f3485041488>, verbose=0)

# %%
cv0_grid = pd.DataFrame(cv0.cv_results_['params'])
cv0_grid['val R2'] = cv0.cv_results_['mean_test_score']
cv0_grid = cv0_grid.sort_values('val R2', ascending=False)

cv1_grid = pd.DataFrame(cv1.cv_results_['params'])
cv1_grid['val R2'] = cv1.cv_results_['mean_test_score']
cv1_grid = cv1_grid.sort_values('val R2', ascending=False)

# %%
print(cv0_grid.head())
print(cv1_grid.head())
# Out:
#       alpha   val R2
# 0  0.000001  0.72557
# 1  0.000001  0.72557
# 2  0.000002  0.72557
# 3  0.000002  0.72557
# 4  0.000003  0.72557
#       alpha   val R2
# 0  0.000001  0.72557
# 1  0.000001  0.72557
# 2  0.000002  0.72557
# 3  0.000002  0.72557
# 4  0.000003  0.72557

# %%
model0 = Lasso(alpha = 0.000001)
model1 = Ridge(alpha = 0.000001)

model0.fit(train_x, train_y)
model1.fit(train_x, train_y)

p0_test = model0.predict(x_test)
p1_test = model1.predict(x_test)

print('R2 Score\n')
print('For Lasso regularization %.3f\n' % r2_score(y_test, p0_test))
print('For Ridge regularization %.3f\n' % r2_score(y_test, p1_test))
# Out:
# R2 Score
#
# For Lasso regularization 0.668
#
# For Ridge regularization 0.668

# %% [markdown]
# >**Заметно ли изменилось качество?**
# Нет, на тысячную долю

# %% [markdown]
# Постройте график зависимости $R^2$ для обучающей и тестовой (на кросс-валидации) выборок в зависимости от значения гиперпараметра. Для Lasso также постройте график зависимости количества ненулевых весов.

# %%
def draw_plot_alpha(alphas, model, score_train, score_test):
    f, ax = plt.subplots(figsize=(13, 5))
    ax.plot(alphas, score_train, label=u"Обучающая")
    ax.plot(alphas, score_test, label=u"Тестовая")
    ax.set_title(u"Зависимость $R^2$ от параметра alpha для " + model)
    ax.set_xlabel(u"Log(alpha)")
    ax.set_ylabel(u"$R^2$ score")
    ax.grid()
    ax.legend()
    f.show()

# %%
def draw_plot_non_zero(alphas, cnt):
    f, ax = plt.subplots(figsize=(13, 5))
    ax.plot(alphas, cnt)#, label=u"")
    ax.set_title(u"Зависимость числа ненулевых весов от параметра alpha для Lasso")
    ax.set_xlabel(u"Log(alpha)")
    ax.set_ylabel(u"Количество")
    ax.grid()
    ax.legend()
    f.show()

# %%
alphas = np.logspace(-6, 6, 100)
cv0_grid = pd.DataFrame(cv0.cv_results_['params'])
cv0_grid['val R2'] = cv0.cv_results_['mean_test_score']

cv1_grid = pd.DataFrame(cv1.cv_results_['params'])
cv1_grid['val R2'] = cv1.cv_results_['mean_test_score']

n = len(alphas)
lasso_score_train = cv0_grid['val R2']
ridge_score_train = cv1_grid['val R2']

lasso_score_test = np.empty(n)
ridge_score_test = np.empty(n)
lasso_nonzero = np.empty(n)

for i in range(n):
    model0 = Lasso(alphas[i])
    model1 = Ridge(alphas[i])

    model0.fit(train_x, train_y)
    model1.fit(train_x, train_y)

    p0_test = model0.predict(x_test)
    p1_test = model1.predict(x_test)

    lasso_score_test[i] = r2_score(y_test, p0_test)
    ridge_score_test[i] = r2_score(y_test, p1_test)
    
    lasso_nonzero[i] = count_nonzero(model0.coef_)

# %%
draw_plot_alpha(np.log10(alphas), 'Lasso', lasso_score_train, lasso_score_test)
draw_plot_alpha(np.log10(alphas), 'Ridge', ridge_score_train, ridge_score_test)
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
draw_plot_non_zero(np.log10(alphas), lasso_nonzero)
# Out:
# /home/fedor/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# В какой момент происходит недообучение? Почему?

# %% [markdown]
# __Ответ__: При alpha > 1000
# Штраф за веса начинает сильно превышать штраф за некорректность предсказания

# %% [markdown]
# ---

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Как вы могли заметить, большого прироста качества с помощью подбора коэфициента регуляризации добиться не удалось. Поэтому прежде чем бросаться обучать модели, необходимо изучить и предобработать данные.

# %% [markdown]
# __Задание 3.__ Масштабирование.
#
# __(1 балл)__
#
# Зачастую признаки в сырых данных имеют разный масштаб. Попробуйте применить масштабирование к данным, сравните качество. Заметно ли изменение?
#
# Pipeline, StandardScaler, MinMaxScaler

# %%
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.preprocessing import StandardScaler

#UNIQUE = {c: data[c][~data[c].isnull()].unique() for c in data.columns[data.dtypes == 'object']}
'''
class MyTransformer(TransformerMixin, BaseEstimator):
    def transform(self, x, y=None):
        data = x.copy()
        return data
    
    def fit(self, x, y=None):
        data = x.copy()
        return self
    
    
class MyScaler_Standart(TransformerMixin, BaseEstimator):
    def __init__(self):
        self.scaler = StandardScaler()
        
    def transform(self, x, y=None):
        x = x.copy()
        x.loc[:, self.clmns] = self.scaler.transform(x[self.clmns])
        return x
    
    def fit(self, x, y=None):
        cond = x.dtypes == 'float'
        self.clmns = cond[cond].index
        self.scaler.fit(x[self.clmns])
        return self
    
class MyScaler_MinMax(TransformerMixin, BaseEstimator):
    def __init__(self):
        self.scaler = MinMaxScaler()
        
    def transform(self, x, y=None):
        x = x.copy()
        x.loc[:, self.clmns] = self.scaler.transform(x[self.clmns])
        return x
    
    def fit(self, x, y=None):
        cond = x.dtypes == 'float'
        self.clmns = cond[cond].index
        self.scaler.fit(x[self.clmns])
        return self
'''
# Out:
# "\nclass MyTransformer(TransformerMixin, BaseEstimator):\n    def transform(self, x, y=None):\n        data = x.copy()\n        return data\n    \n    def fit(self, x, y=None):\n        data = x.copy()\n        return self\n    \n    \nclass MyScaler_Standart(TransformerMixin, BaseEstimator):\n    def __init__(self):\n        self.scaler = StandardScaler()\n        \n    def transform(self, x, y=None):\n        x = x.copy()\n        x.loc[:, self.clmns] = self.scaler.transform(x[self.clmns])\n        return x\n    \n    def fit(self, x, y=None):\n        cond = x.dtypes == 'float'\n        self.clmns = cond[cond].index\n        self.scaler.fit(x[self.clmns])\n        return self\n    \nclass MyScaler_MinMax(TransformerMixin, BaseEstimator):\n    def __init__(self):\n        self.scaler = MinMaxScaler()\n        \n    def transform(self, x, y=None):\n        x = x.copy()\n        x.loc[:, self.clmns] = self.scaler.transform(x[self.clmns])\n        return x\n    \n    def fit(self, x, 
# ...

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('scale', StandardScaler()),
    ('reg', LinearRegression())
])

# %%
params = [{
    'reg': [LinearRegression()],
    'scale': [StandardScaler(), MinMaxScaler()]
}, {
    'reg': [Ridge(), Lasso()], 
    'scale': [StandardScaler(), MinMaxScaler()],
    'reg__alpha': np.logspace(-6, 6, 100)
}]

cv = GridSearchCV(pipe, params, cv=4, scoring=r2_scorer)
cv.fit(train_x, train_y)
# Out:
# GridSearchCV(cv=4, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('reg', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'reg': [LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)], 'scale': [StandardScaler(copy=True, with_mean=True, with_std=True), MinMaxScaler(copy=True, feature_range=(0, 1))]}, {'reg': [Ridge(alpha=0.21544346900318867, copy_X=True, fit_intercept=True,
#    max_i...e=(0, 1))], 'reg__alpha': array([  1.00000e-06,   1.32194e-06, ...,   7.56463e+05,   1.00000e+06])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=<function r2_scorer at 0x7f3485041488>, verbose=0)

# %%
cv_grid = pd.DataFrame(cv.cv_results_['params'])
cv_grid['val R2'] = cv.cv_results_['mean_test_score']
cv_grid['reg'] = cv_grid['reg'].apply(lambda x: x.__class__.__name__)
cv_grid.head()
# Out:
#                 reg  reg__alpha  \
# 0  LinearRegression         NaN
# 1  LinearRegression         NaN
# 2             Ridge    0.000001
# 3             Ridge    0.000001
# 4             Ridge    0.000001
#
#                                                scale   val R2
# 0  StandardScaler(copy=True, with_mean=True, with...  0.72557
# 1      MinMaxScaler(copy=True, feature_range=(0, 1))  0.72557
# 2  StandardScaler(copy=True, with_mean=True, with...  0.72557
# 3      MinMaxScaler(copy=True, feature_range=(0, 1))  0.72557
# 4  StandardScaler(copy=True, with_mean=True, with...  0.72557

# %%
print(cv.best_params_)
# Out:
# {'reg': Ridge(alpha=0.21544346900318867, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001), 'reg__alpha': 0.21544346900318867, 'scale': MinMaxScaler(copy=True, feature_range=(0, 1))}

# %%
print('Test R2 on MinMaxScaler for %s is %.3f' % (cv.best_params_['reg'], r2_scorer(cv, x_test, y_test)))
# Out:
# Test R2 on MinMaxScaler for Ridge(alpha=0.21544346900318867, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001) is 0.671

# %% [markdown]
# Сравните оптимальное значение коэффициента регуляризации для Ridge-регрессии до и после масштабирования. Изменилось ли оно? Предположите, почему так могло произойти.

# %% [markdown]
# *Было:* 0.000001
# *Стало:* 0.21544346900318867

# %% [markdown]
# __Ответ:__ Из-за того, что данные стали нормированны, штраф стал равномерно зависеть от параметров по каждому из них. Благодаря этому из-за больших параметров лучшая alpha не стремилась к нулю. Т.к. при этом к тому же она еще и квадратичная, штраф наибольшего из параметров сильно превышал штраф остальных

# %% [markdown]
# __Задание 4.__ Новые признаки.
#
# __(1.5 балла)__
#
# Полезным также бывает посмотреть как целевая переменная зависит от каждого признака.

# %%
pairplot(x_train, y_train)

# %% [markdown]
# Обратите внимение на зависимость цены от признака LSTAT. Является ли эта зависимость линейной? А какой? Попробуйте выбрать преобразование для этого признака так, чтобы получившаяся зависимость была более линейной. Добейтесь $R^2$ на тестовой выборке не меньше 0.71.

# %% [markdown]
# __Ответ:__ Похоже на корневую функцию, найдем ее перебирая степень

# %%
train_x, test_x = x_train.copy(), x_test.copy()
train_y, test_y = y_train.copy(), y_test.copy()
train_x['LSTAT'] = train_x['LSTAT'] ** 0.2
test_x['LSTAT'] = test_x['LSTAT'] ** 0.2

# %%
pairplot(train_x, train_y)

# %%
cv1 = GridSearchCV(pipe, params, cv=4, scoring=r2_scorer)
cv1.fit(train_x, train_y)
# Out:
# GridSearchCV(cv=4, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('reg', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'reg': [LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)], 'scale': [StandardScaler(copy=True, with_mean=True, with_std=True), MinMaxScaler(copy=True, feature_range=(0, 1))]}, {'reg': [Ridge(alpha=0.21544346900318867, copy_X=True, fit_intercept=True,
#    max_i...e=(0, 1))], 'reg__alpha': array([  1.00000e-06,   1.32194e-06, ...,   7.56463e+05,   1.00000e+06])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=<function r2_scorer at 0x7f3485041488>, verbose=0)

# %%
cv1_grid = pd.DataFrame(cv1.cv_results_['params'])
cv1_grid['val R2'] = cv1.cv_results_['mean_test_score']
#cv1_grid['reg__alpha'] = cv1_grid['reg__alpha'].fillna('0.')
cv1_grid['reg'] = cv1_grid['reg'].apply(lambda x: x.__class__.__name__)
cv1_grid.sort_values('val R2')
cv1_grid.head()
# Out:
#                 reg  reg__alpha  \
# 0  LinearRegression         NaN
# 1  LinearRegression         NaN
# 2             Ridge    0.000001
# 3             Ridge    0.000001
# 4             Ridge    0.000001
#
#                                                scale    val R2
# 0  StandardScaler(copy=True, with_mean=True, with...  0.766546
# 1      MinMaxScaler(copy=True, feature_range=(0, 1))  0.766546
# 2  StandardScaler(copy=True, with_mean=True, with...  0.766546
# 3      MinMaxScaler(copy=True, feature_range=(0, 1))  0.766546
# 4  StandardScaler(copy=True, with_mean=True, with...  0.766546

# %%
print(cv1.best_params_)
# Out:
# {'reg': Ridge(alpha=0.21544346900318867, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001), 'reg__alpha': 0.21544346900318867, 'scale': MinMaxScaler(copy=True, feature_range=(0, 1))}

# %%
print('Test R2 on MinMaxScaler for %s is %.3f' % (cv1.best_params_['reg'], r2_scorer(cv1, test_x, test_y)))
# Out:
# Test R2 on MinMaxScaler for Ridge(alpha=0.21544346900318867, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001) is 0.734

# %% [markdown]
# Помимо преобразований отдельный признаков полезными бывают их попарные взаимодействия. Воспользуйтесь PolynomialFeatures, чтобы добавить попарные произведения и квадраты всех признаков. Обучите Ridge-регрессию (подберите гиперпараметр!) и посчитайте $R^2$ на тесте. Сильно ли изменилось качество?

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2)

# %% [markdown]
# __Задание 5.__ Оптимальная архитектура, анализ.
#
# __(2 балла)__
#
# При помощи `Pipeline` и `GridSearchSCV` выберите оптимальную архитектуру, комбинируя различные методы масштабирования, степень полинома в `PolynomialFeatures`, а также регуляризаторы. Для `Lasso` поставьте максимальное количество итераций больше значения по умолчанию, чтобы оптимизация сошлась.

# %%
#  Your code here
# ...

# %% [markdown]
# Для одной комбинаций метода масштабирования и линейной регрессии постройте зависимость метрики $R^2$ на кросс-валидации (`GridSearchCV.cv_results_['mean_test_score']`) от значения параметра регуляризации для различных степеней полиномов в `PolynomialFeatures`.

# %%
#  Your code here
# ...

# %% [markdown]
# При каких значениях происходит переобучение? А недообучение? Почему?

# %% [markdown]
# __Ответ:__

# %% [markdown]
# **Ссылки:**
# *Задача 5*
# https://pythonexample.com/code/numpy-run-length-encoding/

# %% [markdown]
# **Оценка:** 7???
